# %%
#@title Run Gradio App
# %cd /content/
# !git clone https://github.com/NeuralFalconYT/Remove-Silence-From-Audio.git
# %cd Remove-Silence-From-Audio
# !pip install -r requirements.txt
from IPython.display import clear_output
clear_output()
# !python app.py --share --debug
# Out:
# /content/Remove-Silence-From-Audio/app.py:106: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css) as demo:
# /content/Remove-Silence-From-Audio/app.py:106: DeprecationWarning: The 'css' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'css' to Blocks.launch() instead.
#   with gr.Blocks(theme=theme, css=css) as demo:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://aa8d972aef97baea90.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
